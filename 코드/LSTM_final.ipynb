# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.6f}'.format

# 그래프에서 한글 깨짐 방지
import platform
if platform.system() == "Darwin":          # MAC인 경우
    plt.rc('font', family ="AppleGothic")
else:
    plt.rc('font',family='Malgun Gothic')

#멧플로립에서 음수를 표시
plt.rc('axes',unicode_minus=False)

#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 1.스케일링(standard_scale)

# %%
# 데이터 불러오기
df = pd.read_csv('./datasets/원본data.csv')
df['Date'] = pd.to_datetime(df['Date'])  # 'Date' 열을 datetime 객체로 변환
df.set_index('Date', inplace=True)

df=df.drop(['원위안', '유가', '은', '외환보유액','구리'],axis=1) # G7 이미 삭제된 데이터셋
dataset =df.values
# dataset=df[['재고순환지표','경제심리지수','수출입물가비율','코스피','장단기','원달러','CD','G20','종가']].values
scaler=StandardScaler()
dataset= scaler.fit_transform(dataset)
print(dataset)
# Out:
# [[ 0.93589755  1.43327182 -0.74157178 ...  2.07114449 -1.74913464
#   -1.49457805]
#  [ 0.80523213  1.42294476 -0.75485022 ...  2.01342627 -1.57284691
#   -1.75012721]
#  [ 0.7220814   1.26803893 -0.75485022 ...  2.85611229 -1.33988349
#   -1.81061445]
#  ...
#  [-1.58238152 -0.73540982  0.37381684 ... -0.75285063  1.76937084
#   -0.3938106 ]
#  [-1.61801754 -0.73540982 -0.40961088 ... -0.59701144  1.4817088
#   -0.27075728]
#  [-1.66553224 -0.61148516 -0.3432187  ... -0.94751845  1.95422583
#   -0.27316174]]

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# - scaled_df : 5개의 feature 삭제하고 남은 전체 데이터프레임
# - feature_df : scaled_df중 종가를 제외한 부분
# - label_df : scaled_df의 종가 부분

# %%
scaled_df = pd.DataFrame(dataset, columns=df.columns,index=df.index)
feature_df = scaled_df[['재고순환지표', '경제심리지수', '기계류내수출', '건설수주액', '수출입물가비율', '코스피', '장단기', '뉴스심리지수', '원달러', '원엔', 'CD', 'G20', '미장단기', '거래량', '천연가스', '금','종가']]
label_df = scaled_df['종가']

# %% [markdown]
# #### 사용한 데이터 :  내생 변수 -> 9개

# %%
feature_df_2 = feature_df[['재고순환지표','경제심리지수','수출입물가비율','코스피','장단기','원달러','CD','G20','종가']]

# %% [markdown]
# ## 2.tesnorflow에 사용될 데이터로 전처리

# %% [markdown]
# ### 데이터프레임을 --> array형태로

# %%
feature_np = feature_df_2.to_numpy()
label_np = label_df.to_numpy()

# %%
feature_np.shape
# Out:
# (184, 9)

# %% [markdown]
# ### tensorflow에서 사용하기 위한 데이터 형태 만들기
#     - feature : 학습시킬 데이터
#     - label : 예측할 데이터
#     - window_size : 몇개 전 데이터로 다음값을 예측할 것인지
#     - return: (row 총 개수 - windows , window_size , feature 개수) , (row 총 개수 - windows, )

# %% [markdown]
# #### 1. window로 3차원 텐서로 만들기

# %%
def make_sequence_dataset(feature, label, window_size):
  feature_list = []
  label_list = []

  for i in range(len(feature)-window_size):
    feature_list.append(feature[i:i+window_size])
    label_list.append(label[i+window_size-1])

  return np.array(feature_list), np.array(label_list) # 3차원 텐서

# %%
window_size=1
X, Y = make_sequence_dataset(feature_np, label_np, window_size) # batchsize, time steps ,input dims
print(X.shape,Y.shape)
# Out:
# (183, 1, 9) (183,)

# %% [markdown]
# #### 2. train,test으로 데이터 분할
#     - split : 테스트 개수

# %%
split = -36
x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape,x_test.shape, y_test.shape)
# Out:
# (147, 1, 9) (147,) (36, 1, 9) (36,)

# %% [markdown]
# ## 3. LSTM 모델링

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.utils import get_custom_objects

def prelu_activation(x):
    alpha = tf.constant(0.1)  # P-ReLU 매개변수
    return tf.keras.activations.relu(x) - alpha * tf.keras.activations.relu(-x)

get_custom_objects().update({'prelu_activation': prelu_activation})


def e_relu_activation(x):
    alpha = tf.constant(1.0)  # e-ReLU 매개변수
    return tf.keras.activations.relu(x) - alpha * (tf.exp(x) - 1)

get_custom_objects().update({'e_relu_activation': e_relu_activation})


# LSTM 모델 생성
from keras.layers import Bidirectional

model = Sequential()
model.add(Bidirectional(LSTM(256, return_sequences=True, dropout=0.18,recurrent_dropout =0.15,activation='e_relu_activation'), input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Bidirectional(LSTM(128, return_sequences=True, dropout=0.18, recurrent_dropout=0.15,activation='tanh')))
model.add(Bidirectional(LSTM(128, return_sequences=False, dropout=0.18, recurrent_dropout=0.15,activation='e_relu_activation')))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 1, 512)           544768
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 1, 256)           656384
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256)              394240
#  nal)
#
#  dense (Dense)               (None, 1)                 257
#
# =================================================================
# Total params: 1,595,649
# Trainable params: 1,595,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
# early_stop = EarlyStopping(monitor='val_loss', patience=5)
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=130, batch_size=6, verbose=1)
# Out:
# Epoch 1/130
# 25/25 [==============================] - 12s 50ms/step - loss: 1.1424 - val_loss: 0.4459
# Epoch 2/130
# 25/25 [==============================] - 0s 15ms/step - loss: 1.1310 - val_loss: 0.4162
# Epoch 3/130
# 25/25 [==============================] - 0s 15ms/step - loss: 0.8653 - val_loss: 0.3711
# Epoch 4/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.8170 - val_loss: 0.3338
# Epoch 5/130
# 25/25 [==============================] - 0s 16ms/step - loss: 0.6428 - val_loss: 0.2954
# Epoch 6/130
# 25/25 [==============================] - 0s 16ms/step - loss: 0.5937 - val_loss: 0.2945
# Epoch 7/130
# 25/25 [==============================] - 0s 16ms/step - loss: 0.5246 - val_loss: 0.2484
# Epoch 8/130
# 25/25 [==============================] - 0s 16ms/step - loss: 0.2725 - val_loss: 0.1943
# Epoch 9/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2515 - val_loss: 0.1740
# Epoch 10/130
# 25/25 [==============================] - 0s 16ms/step - loss: 0.1831 - val_loss: 0.1473
# Epoch 11/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1532 - val_loss: 0.1369
# Epoch 12/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1071 - val_loss: 0.1168
# Epoch 13/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1151 - val_loss: 0.1040
# Epoch 14/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0902 - val_loss: 0.0928
# Epoch 15/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0896 - val_loss: 0.0704
# Epoch 16/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0789 - val_loss: 0.0809
# Epoch 17/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0722 - val_loss: 0.0587
# Epoch 18/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0636 - val_loss: 0.0335
# Epoch 19/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0627 - val_loss: 0.0319
# Epoch 20/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0551 - val_loss: 0.0342
# Epoch 21/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0537 - val_loss: 0.0518
# Epoch 22/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0540 - val_loss: 0.0410
# Epoch 23/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0457 - val_loss: 0.0509
# Epoch 24/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0547 - val_loss: 0.0699
# Epoch 25/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0473 - val_loss: 0.0584
# Epoch 26/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0375 - val_loss: 0.0497
# Epoch 27/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0355 - val_loss: 0.0508
# Epoch 28/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0336 - val_loss: 0.0652
# Epoch 29/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0435 - val_loss: 0.0489
# Epoch 30/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0380 - val_loss: 0.0452
# Epoch 31/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0359 - val_loss: 0.0434
# Epoch 32/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0396 - val_loss: 0.0398
# Epoch 33/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0276 - val_loss: 0.0377
# Epoch 34/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0296 - val_loss: 0.0423
# Epoch 35/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0257 - val_loss: 0.0445
# Epoch 36/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0334 - val_loss: 0.0398
# Epoch 37/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0278 - val_loss: 0.0431
# Epoch 38/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0238 - val_loss: 0.0501
# Epoch 39/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0322 - val_loss: 0.0465
# Epoch 40/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0287 - val_loss: 0.0391
# Epoch 41/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0247 - val_loss: 0.0453
# Epoch 42/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0347 - val_loss: 0.0499
# Epoch 43/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0261 - val_loss: 0.0408
# Epoch 44/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0275 - val_loss: 0.0368
# Epoch 45/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0311 - val_loss: 0.0311
# Epoch 46/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0273 - val_loss: 0.0342
# Epoch 47/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0223 - val_loss: 0.0398
# Epoch 48/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0365 - val_loss: 0.0429
# Epoch 49/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0314 - val_loss: 0.0388
# Epoch 50/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0293 - val_loss: 0.0413
# Epoch 51/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0346 - val_loss: 0.0415
# Epoch 52/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0278 - val_loss: 0.0357
# Epoch 53/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0205 - val_loss: 0.0417
# Epoch 54/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0259 - val_loss: 0.0466
# Epoch 55/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0288 - val_loss: 0.0544
# Epoch 56/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0374 - val_loss: 0.0362
# Epoch 57/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0226 - val_loss: 0.0511
# Epoch 58/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0232 - val_loss: 0.0548
# Epoch 59/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0239 - val_loss: 0.0547
# Epoch 60/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0231 - val_loss: 0.0441
# Epoch 61/130
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0227 - val_loss: 0.0526
# Epoch 62/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0292 - val_loss: 0.0387
# Epoch 63/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0260 - val_loss: 0.0413
# Epoch 64/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0210 - val_loss: 0.0368
# Epoch 65/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0282 - val_loss: 0.0390
# Epoch 66/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0176 - val_loss: 0.0386
# Epoch 67/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0223 - val_loss: 0.0467
# Epoch 68/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0224 - val_loss: 0.0297
# Epoch 69/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0234 - val_loss: 0.0294
# Epoch 70/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0227 - val_loss: 0.0362
# Epoch 71/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0248 - val_loss: 0.0378
# Epoch 72/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0154 - val_loss: 0.0353
# Epoch 73/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0213 - val_loss: 0.0319
# Epoch 74/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0204 - val_loss: 0.0409
# Epoch 75/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0201 - val_loss: 0.0424
# Epoch 76/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0174 - val_loss: 0.0374
# Epoch 77/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0205 - val_loss: 0.0323
# Epoch 78/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0318 - val_loss: 0.0306
# Epoch 79/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0259 - val_loss: 0.0270
# Epoch 80/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0173 - val_loss: 0.0310
# Epoch 81/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0158 - val_loss: 0.0314
# Epoch 82/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0180 - val_loss: 0.0325
# Epoch 83/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0217 - val_loss: 0.0332
# Epoch 84/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0201 - val_loss: 0.0286
# Epoch 85/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0182 - val_loss: 0.0317
# Epoch 86/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0173 - val_loss: 0.0315
# Epoch 87/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0205 - val_loss: 0.0327
# Epoch 88/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0202 - val_loss: 0.0323
# Epoch 89/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0336
# Epoch 90/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0178 - val_loss: 0.0314
# Epoch 91/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0221 - val_loss: 0.0347
# Epoch 92/130
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0168 - val_loss: 0.0263
# Epoch 93/130
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0203 - val_loss: 0.0285
# Epoch 94/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0278
# Epoch 95/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0206 - val_loss: 0.0259
# Epoch 96/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0149 - val_loss: 0.0305
# Epoch 97/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0197 - val_loss: 0.0346
# Epoch 98/130
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0177 - val_loss: 0.0293
# Epoch 99/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0148 - val_loss: 0.0298
# Epoch 100/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0158 - val_loss: 0.0361
# Epoch 101/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0296
# Epoch 102/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0185 - val_loss: 0.0249
# Epoch 103/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0144 - val_loss: 0.0270
# Epoch 104/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0151 - val_loss: 0.0266
# Epoch 105/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0236 - val_loss: 0.0304
# Epoch 106/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0151 - val_loss: 0.0253
# Epoch 107/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0196 - val_loss: 0.0244
# Epoch 108/130
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0135 - val_loss: 0.0227
# Epoch 109/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0167 - val_loss: 0.0273
# Epoch 110/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0134 - val_loss: 0.0286
# Epoch 111/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0211 - val_loss: 0.0359
# Epoch 112/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0204 - val_loss: 0.0353
# Epoch 113/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0134 - val_loss: 0.0343
# Epoch 114/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0277
# Epoch 115/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0129 - val_loss: 0.0317
# Epoch 116/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0139 - val_loss: 0.0326
# Epoch 117/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0234 - val_loss: 0.0194
# Epoch 118/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0137 - val_loss: 0.0219
# Epoch 119/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0197 - val_loss: 0.0227
# Epoch 120/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0174 - val_loss: 0.0268
# Epoch 121/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0153 - val_loss: 0.0252
# Epoch 122/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0135 - val_loss: 0.0224
# Epoch 123/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0125 - val_loss: 0.0255
# Epoch 124/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0138 - val_loss: 0.0254
# Epoch 125/130
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0153 - val_loss: 0.0282
# Epoch 126/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0139 - val_loss: 0.0267
# Epoch 127/130
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0130 - val_loss: 0.0248
# Epoch 128/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0124 - val_loss: 0.0284
# Epoch 129/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0115 - val_loss: 0.0174
# Epoch 130/130
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0102 - val_loss: 0.0182

# %% [markdown]
# ## 4.예측 및 시각화

# %%
# 예측
val_predict = model.predict(x_test)

# 역 변환기
scaler_y = StandardScaler()
scaled_data_y = scaler_y.fit_transform(df.iloc[:, -1].values.reshape(-1,1))

# 예측 값 스케일 역변환
val_predict = scaler_y.inverse_transform(val_predict)

# 실제 값 스케일 역변환
y_train = scaler_y.inverse_transform(y_train.reshape(-1,1))
y_test = scaler_y.inverse_transform(y_test.reshape(-1,1))

plt.figure(figsize=(10,6))
# Add the training set to the plot:
plt.plot(y_train, color='green', label='Train')
# Plot the test and prediction data:
plt.plot(range(len(y_train), len(y_train)+len(y_test)), y_test, color='blue', label='Real')
plt.plot(range(len(y_train), len(y_train)+len(y_test)), val_predict, color='red', label='Prediction')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 1s 3ms/step

# %%
val_predict
# Out:
# array([[ 922.4924],
#        [ 970.6705],
#        [1100.1455],
#        [1171.6609],
#        [1242.9229],
#        [1334.2938],
#        [1367.1554],
#        [1355.2076],
#        [1431.4348],
#        [1600.5668],
#        [1915.3651],
#        [1847.92  ],
#        [1841.8848],
#        [1812.3778],
#        [1952.8112],
#        [1986.8273],
#        [1891.3046],
#        [1886.4153],
#        [1731.385 ],
#        [1805.6921],
#        [1649.6355],
#        [1752.319 ],
#        [1590.8301],
#        [1528.9836],
#        [1581.7947],
#        [1652.1311],
#        [1689.953 ],
#        [1509.6239],
#        [1610.2063],
#        [1544.4928],
#        [1397.9141],
#        [1341.7616],
#        [1495.7057],
#        [1416.4714],
#        [1500.5272],
#        [1485.5018]], dtype=float32)

# %%
# 예측

plt.figure(figsize=(7,4))
plt.title('LSTM')
plt.ylabel('price(won)')
plt.xlabel('period(month)')
plt.plot(val_predict[2:], label = 'Prediction', color='r')
plt.plot(y_test[2:], label = 'actual', color='b')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## 5. 평가지표

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

#Calculate mean absolute error
mae = mean_absolute_error(val_predict[2:],y_test[2:])
print('MAE: %f' % mae)

#Calculate mean squared error and root mean squared error
mse = mean_squared_error(val_predict[2:], y_test[2:])
print('MSE: %f' % mse)
rmse = np.sqrt(mse)
print('RMSE: %f' % rmse)

#Calculate mean_absolute_percentage_error
mape = mean_absolute_percentage_error(val_predict[2:],y_test[2:])
print('MAPE: %f' % mape)
# Out:
# MAE: 42.696038
# MSE: 2901.825155
# RMSE: 53.868592
# MAPE: 0.028601

# %%
pred = pd.Series(val_predict.flatten()).pct_change()
test = pd.Series(y_test.flatten()).pct_change()

# %%
re = 1
for i in range(len(pred)):
  if pred[i] > 0:
    re *= (1+test[i])

re
# Out:
# 3.2483523697138175

# %%
df = pd.DataFrame({
    '예측': val_predict.flatten(),
    '종가': y_test.flatten()
})
# df

# %%
df['trade'] = ''

df['trade'] = np.where(df['예측'].shift(-1) > df['예측'], 'buy', '')
df['buy_price'] = df.loc[df['trade'] == 'buy', '종가']
df['next_day_price'] = df['종가'].shift(-1)  # 다음 날의 종가를 새로운 컬럼으로 추가
df['profit'] = np.where(df['trade'] == 'buy', df['next_day_price'] - df['buy_price'], np.nan)  # 수익 계산
df['return'] = df['profit'] / df['buy_price']  # 수익률 계산
df['profit'] = df['profit'].fillna(0)
df['return'] = df['return'].fillna(0)
# df
# Out:
#             예측          종가 trade   buy_price  next_day_price     profit
# 0   922.492371  932.770000   buy  932.770000     1047.710000 114.940000  \
# 1   970.670471 1047.710000   buy 1047.710000     1156.360000 108.650000
# 2  1100.145508 1156.360000   buy 1156.360000     1118.170000 -38.190000
# 3  1171.660889 1118.170000   buy 1118.170000     1213.420000  95.250000
# 4  1242.922852 1213.420000   buy 1213.420000     1424.680000 211.260000
# 5  1334.293823 1424.680000   buy 1424.680000     1468.870000  44.190000
# 6  1367.155396 1468.870000               NaN     1418.120000   0.000000
# 7  1355.207642 1418.120000   buy 1418.120000     1562.350000 144.230000
# 8  1431.434814 1562.350000   buy 1562.350000     1731.680000 169.330000
# 9  1600.566772 1731.680000   buy 1731.680000     1960.990000 229.310000
# 10 1915.365112 1960.990000               NaN     1883.220000   0.000000
# 11 1847.920044 1883.220000               NaN     1869.780000   0.000000
# 12 1841.884766 1869.780000               NaN     1843.210000   0.000000
# 13 1812.377808 1843.210000   buy 1843.210000     1993.780000 150.570000
# 14 1952.811157 1993.780000   buy 1993.780000     2022.760000  28.980000
# 15 1986.827271 2022.760000               NaN     1903.470000   0.000000
# 16 1891.304565 1903.470000               NaN     1879.970000   0.000000
# 17 1886.415283 1879.970000               NaN     1722.250000   0.000000
# 18 1731.385010 1722.250000   buy 1722.250000     1780.740000  58.490000
# 19 1805.692139 1780.740000               NaN     1641.230000   0.000000
# 20 1649.635498 1641.230000   buy 1641.230000     1740.030000  98.800000
# 21 1752.318970 1740.030000               NaN     1601.520000   0.000000
# 22 1590.830078 1601.520000               NaN     1537.130000   0.000000
# 23 1528.983643 1537.130000   buy 1537.130000     1561.680000  24.550000
# 24 1581.794678 1561.680000   buy 1561.680000     1609.620000  47.940000
# 25 1652.131104 1609.620000   buy 1609.620000     1619.700000  10.080000
# 26 1689.953003 1619.700000               NaN     1479.700000   0.000000
# 27 1509.623901 1479.700000   buy 1479.700000     1576.960000  97.260000
# 28 1610.206299 1576.960000               NaN     1552.160000   0.000000
# 29 1544.492798 1552.160000               NaN     1433.220000   0.000000
# 30 1397.914062 1433.220000               NaN     1392.690000   0.000000
# 31 1341.761597 1392.690000   buy 1392.690000     1435.740000  43.050000
# 32 1495.705688 1435.740000               NaN     1343.910000   0.000000
# 33 1416.471436 1343.910000   buy 1343.910000     1439.490000  95.580000
# 34 1500.527222 1439.490000               NaN     1488.620000   0.000000
# 35 1485.501831 1488.620000               NaN             NaN   0.000000
#
#       return
# 0   0.123224
# 1   0.103702
# 2  -0.033026
# 3   0.085184
# 4   0.174103
# 5   0.031017
# 6   0.000000
# 7   0.101705
# 8   0.108382
# 9   0.132421
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.081689
# 14  0.014535
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.033961
# 19  0.000000
# 20  0.060199
# 21  0.000000
# 22  0.000000
# 23  0.015971
# 24  0.030698
# 25  0.006262
# 26  0.000000
# 27  0.065730
# 28  0.000000
# 29  0.000000
# 30  0.000000
# 31  0.030911
# 32  0.000000
# 33  0.071121
# 34  0.000000
# 35  0.000000

# %%
ret = 1
cum_ret = []
for value in df['return']:
    if not pd.isnull(value):
        ret *= (1 + value)
    cum_ret.append(ret)
df['누적 수익률'] = cum_ret
df
# Out:
#             예측          종가 trade   buy_price  next_day_price     profit
# 0   922.492371  932.770000   buy  932.770000     1047.710000 114.940000  \
# 1   970.670471 1047.710000   buy 1047.710000     1156.360000 108.650000
# 2  1100.145508 1156.360000   buy 1156.360000     1118.170000 -38.190000
# 3  1171.660889 1118.170000   buy 1118.170000     1213.420000  95.250000
# 4  1242.922852 1213.420000   buy 1213.420000     1424.680000 211.260000
# 5  1334.293823 1424.680000   buy 1424.680000     1468.870000  44.190000
# 6  1367.155396 1468.870000               NaN     1418.120000   0.000000
# 7  1355.207642 1418.120000   buy 1418.120000     1562.350000 144.230000
# 8  1431.434814 1562.350000   buy 1562.350000     1731.680000 169.330000
# 9  1600.566772 1731.680000   buy 1731.680000     1960.990000 229.310000
# 10 1915.365112 1960.990000               NaN     1883.220000   0.000000
# 11 1847.920044 1883.220000               NaN     1869.780000   0.000000
# 12 1841.884766 1869.780000               NaN     1843.210000   0.000000
# 13 1812.377808 1843.210000   buy 1843.210000     1993.780000 150.570000
# 14 1952.811157 1993.780000   buy 1993.780000     2022.760000  28.980000
# 15 1986.827271 2022.760000               NaN     1903.470000   0.000000
# 16 1891.304565 1903.470000               NaN     1879.970000   0.000000
# 17 1886.415283 1879.970000               NaN     1722.250000   0.000000
# 18 1731.385010 1722.250000   buy 1722.250000     1780.740000  58.490000
# 19 1805.692139 1780.740000               NaN     1641.230000   0.000000
# 20 1649.635498 1641.230000   buy 1641.230000     1740.030000  98.800000
# 21 1752.318970 1740.030000               NaN     1601.520000   0.000000
# 22 1590.830078 1601.520000               NaN     1537.130000   0.000000
# 23 1528.983643 1537.130000   buy 1537.130000     1561.680000  24.550000
# 24 1581.794678 1561.680000   buy 1561.680000     1609.620000  47.940000
# 25 1652.131104 1609.620000   buy 1609.620000     1619.700000  10.080000
# 26 1689.953003 1619.700000               NaN     1479.700000   0.000000
# 27 1509.623901 1479.700000   buy 1479.700000     1576.960000  97.260000
# 28 1610.206299 1576.960000               NaN     1552.160000   0.000000
# 29 1544.492798 1552.160000               NaN     1433.220000   0.000000
# 30 1397.914062 1433.220000               NaN     1392.690000   0.000000
# 31 1341.761597 1392.690000   buy 1392.690000     1435.740000  43.050000
# 32 1495.705688 1435.740000               NaN     1343.910000   0.000000
# 33 1416.471436 1343.910000   buy 1343.910000     1439.490000  95.580000
# 34 1500.527222 1439.490000               NaN     1488.620000   0.000000
# 35 1485.501831 1488.620000               NaN             NaN   0.000000
#
#       return   누적 수익률
# 0   0.123224 1.123224
# 1   0.103702 1.239705
# 2  -0.033026 1.198763
# 3   0.085184 1.300878
# 4   0.174103 1.527365
# 5   0.031017 1.574740
# 6   0.000000 1.574740
# 7   0.101705 1.734899
# 8   0.108382 1.922930
# 9   0.132421 2.177565
# 10  0.000000 2.177565
# 11  0.000000 2.177565
# 12  0.000000 2.177565
# 13  0.081689 2.355448
# 14  0.014535 2.389685
# 15  0.000000 2.389685
# 16  0.000000 2.389685
# 17  0.000000 2.389685
# 18  0.033961 2.470842
# 19  0.000000 2.470842
# 20  0.060199 2.619584
# 21  0.000000 2.619584
# 22  0.000000 2.619584
# 23  0.015971 2.661422
# 24  0.030698 2.743122
# 25  0.006262 2.760300
# 26  0.000000 2.760300
# 27  0.065730 2.941733
# 28  0.000000 2.941733
# 29  0.000000 2.941733
# 30  0.000000 2.941733
# 31  0.030911 3.032667
# 32  0.000000 3.032667
# 33  0.071121 3.248352
# 34  0.000000 3.248352
# 35  0.000000 3.248352
